# %% [markdown]
# <a href="https://colab.research.google.com/github/tapeshsharma676-hue/AlgoLab_241B706/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Quest 1

# %%
n= int(input("Enter the Number of Nodes:"))
dict1={}
for i in range(n):
  key1= input("Enter The Node: ")
  n1= int(input("Enter the Numbert of nodes connected to:"))
  dict2={}

  for j in range(n1):
    key2=input("Enter The Node: ")
    value2= int(input("Enter an integer value:"))
    dict2[key2]= value2
    dict1[key1]=dict2
print(dict1)
result=dijkstra(dict1,'A')
for node in result:
  print("Distance Fom A To", node,"=", result[node])
# Out:
# Enter the Number of Nodes:2
# Enter The Node: A
# Enter the Numbert of nodes connected to:4
# Enter The Node: B
# Enter an integer value:4
# Enter The Node: A
# Enter an integer value:3
# Enter The Node: B
# Enter an integer value:7
# Enter The Node: C
# Enter an integer value:5
# Enter The Node: B
# Enter the Numbert of nodes connected to:6\
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_18360/769085346.py in <cell line: 0>()
#       3 for i in range(n):
#       4   key1= input("Enter The Node: ")
# ----> 5   n1= int(input("Enter the Numbert of nodes connected to:"))
#       6   dict2={}
#       7
#
# ValueError: invalid literal for int() with base 10: '6\\'

# %% [markdown]
# Quest 3

# %%
graph = {
'A': {'B': 8, 'C': 6},
'B': {'A': 2, 'C': 6, 'D': 10},
'C': {'A': 1, 'B': 7, 'D': 9, 'E':3},
'D': {'B': 8, 'C': 2},
'E':{'C':9, 'D':8, 'F':10},
'F':{'E':6}
  }

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
