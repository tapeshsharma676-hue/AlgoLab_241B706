# %% [markdown]
# <a href="https://colab.research.google.com/github/tapeshsharma676-hue/AlgoLab_241B706/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost

        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %%
g = [
    [0, 10, 15, 20],
    [10, 0, 35, 25],
    [15, 35, 0, 30],
    [20, 25, 30, 0]
]

n = 4
routes = []

for a in range(1, n):
    for b in range(1, n):
        for c in range(1, n):
            if a != b and b != c and a != c:
                routes.append([a, b, c])

best = 999999
best_path = []

for r in routes:
    path = [0] + r + [0] # Start at 0, visit the middle cities, end at 0
    cost = 0

    for i in range(len(path) - 1):
        start = path[i]
        end = path[i+1]
        cost = cost + g[start][end]

    if cost < best:
        best = cost
        best_path = path

print("Lowest travelling cost:", best)
print("Path visited:", best_path)
# Out:
# Lowest travelling cost: 80
# Path visited: [0, 1, 3, 2, 0]

# %%
n = int(input("Enter number of cities: "))

g = []
print("Enter the distances row by row (separated by spaces):")
for i in range(n):
    row = list(map(int, input().split()))
    g.append(row)

routes = [[]]
for step in range(n - 1):
    new_routes = []
    for r in routes:
        for city in range(1, n):
            if city not in r:
                new_routes.append(r + [city])
    routes = new_routes

best = 999999
best_path = []

for r in routes:
    path = [0] + r + [0]
    cost = 0

    for i in range(len(path) - 1):
        start = path[i]
        end = path[i+1]
        cost = cost + g[start][end]

    if cost < best:
        best = cost
        best_path = path

print("\nLowest cost:", best)
print("Path visited:", best_path)
# Out:
# Enter number of cities: 4
# Enter the distances row by row (separated by spaces):
# 0 19 82 74
# 12 0 32 65
# 23 43 0 32
# 82 92 29 0
#
# Lowest cost: 136
# Path visited: [0, 1, 3, 2, 0]

# %%
print("--- Test 1: 3 Cities ---")
g1 = [
    [0, 10, 15],
    [10, 0, 20],
    [15, 20, 0]
]
n1 = 3

routes1 = [[1, 2], [2, 1]]
best1 = 999999
best_path1 = []

for r in routes1:
    path = [0] + r + [0]
    cost = 0
    for i in range(len(path) - 1):
        cost = cost + g1[path[i]][path[i+1]]
    if cost < best1:
        best1 = cost
        best_path1 = path

print("Lowest cost:", best1)
print("Path:", best_path1)


print("\n--- Test 2: 4 Cities ---")
g2 = [
    [0, 12, 10, 19],
    [12, 0, 3, 7],
    [10, 3, 0, 6],
    [19, 7, 6, 0]
]
n2 = 4
routes2 = []

for a in range(1, n2):
    for b in range(1, n2):
        for c in range(1, n2):
            if a != b and b != c and a != c:
                routes2.append([a, b, c])

best2 = 999999
best_path2 = []

for r in routes2:
    path = [0] + r + [0]
    cost = 0
    for i in range(len(path) - 1):
        cost = cost + g2[path[i]][path[i+1]]
    if cost < best2:
        best2 = cost
        best_path2 = path

print("Lowest cost:", best2)
print("Path:", best_path2)
# Out:
# --- Test 1: 3 Cities ---
# Lowest cost: 45
# Path: [0, 1, 2, 0]
#
# --- Test 2: 4 Cities ---
# Lowest cost: 35
# Path: [0, 1, 3, 2, 0]

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities
